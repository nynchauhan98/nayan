# %% [markdown]
# # Supermarket Sales Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('supermarket_sales.csv')
df.head()
# Out:
#     Invoice ID Branch Region      City Customer type  Gender  \
# 0  750-67-8428      A  North     Delhi        Member    Male
# 1  226-31-3081      C  South  Banglore        Normal    Male
# 2  631-41-3108      A  North     Delhi        Normal  Female
# 3  123-19-1176      A  North     Delhi        Member  Female
# 4  373-73-7910      A  North     Delhi        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%   Total        Date  \
# 0       Health and beauty       74.69         7   26.14  548.97  01-05-2019
# 1  Electronic accessories       15.28         5    3.82   80.22  03-08-2019
# 2      Home and lifestyle       46.33         7   16.22  340.53  03-03-2019
# 3       Health and beauty       58.22         8   23.29  489.05  27-01-2019
# 4       Sports and travel       86.31         7   30.21  634.38  25-02-2019
#
#           Time     Month      Payment    cogs  gross margin percentage  \
# ...

# %%
df.shape
# Out:
# (1000, 19)

# %% [markdown]
# Supermarket sales data has 19 Columns & 1000 Rows.

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.380050   322.967430   307.58738
# std      26.494628     2.923431    11.709047   245.885557   234.17651
# min      10.080000     1.000000     0.510000    10.680000    10.17000
# 25%      32.875000     3.000000     5.927500   124.425000   118.49750
# 50%      55.230000     5.000000    12.090000   253.850000   241.76000
# 75%      77.935000     8.000000    22.445000   471.350000   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.760000e+00     14.641220     6.97270
# std               1.208527e-13     11.146698     1.71858
# min               4.760000e+00      0.480000     4.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   Region                   1000 non-null   object
#  3   City                     1000 non-null   object
#  4   Customer type            1000 non-null   object
#  5   Gender                   1000 non-null   object
#  6   Product line             1000 non-null   object
#  7   Unit price               1000 non-null   float64
#  8   Quantity                 1000 non-null   int64
#  9   Tax 5%                   1000 non-null   float64
#  10  Total                    1000 non-null   float64
#  11  Date                     1000 non-null   object
#  12  Time                     1000 non-null   object
#  13  Month                    1000 non-null   object
# ...

# %% [markdown]
# Dtypes of the DataFrame is 6 - float64 / 1 - int64 / 12 - object columns.

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# Region                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Month                      0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# There is no null values in the data set.

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'Region', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Month', 'Payment', 'cogs', 'gross margin percentage',
#        'gross income', 'Rating'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize = (18,6))
sns.scatterplot(data=df, x="Month", y="Total", color="c")  
plt.show()

# %% [markdown]
# In scatter plot you can see more sales are achived in Jan, Feb, Mar.

# %%
plt.figure(figsize = (18,6))
sns.scatterplot(data=df, x="Month", y="Total", hue="Gender", color="c")  
plt.show()

# %% [markdown]
# In scatter plot you can see more sales are achived in Jan, Feb, Mar by Gender

# %%
sns.countplot(df.City, hue=df.Gender)
plt.show()

# %% [markdown]
# In the count plot it can be seen that majorly the customers in Delhi is Female population and in Banglore it's from the Male population

# %% [markdown]
# ### Plotting for different payment methods count

# %%
payment_df = pd.DataFrame(df['Payment'].value_counts())
payment_df
# Out:
#              Payment
# Ewallet          345
# Cash             344
# Credit card      311

# %%
sns.barplot(x =payment_df.index , y = payment_df.Payment)
plt.show()

# %% [markdown]
# The bar plot shows in overall Region that the payment recieved is more from Ewallet then cash then credit card.

# %%
sns.countplot(x="Gender", hue="Payment", data=df, palette="hot")
plt.show()

# %% [markdown]
# Most Males prefer to pay by cash and most Female prefers to pay by Ewallet in overall Region.

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'Region', y = 'Total', data = df, palette="hot")
plt.show()

# %% [markdown]
# The barplot shows that More sales growth is achieved from south region.

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'Region', y = 'Total', data = df, hue="Gender", palette="hot")
plt.show()

# %%
plt.figure(figsize = (18,6))
sns.barplot(x = 'Month', y = 'Total', hue="Gender", data = df, palette="hot")
plt.show()

# %% [markdown]
# The barplot shows Month on month Sales for male and female population from all region.

# %% [markdown]
# ### Creating dummies for Gender column to get numeric data for seaborn bar plot

# %%
gender_dummies  = pd.get_dummies(df['Gender'])
gender_dummies.head()
# Out:
#    Female  Male
# 0       0     1
# 1       0     1
# 2       1     0
# 3       1     0
# 4       1     0

# %% [markdown]
# ### Joining original data frame (df) with gender dummies data frame (gender_dummies)

# %%
df = pd.concat([df, gender_dummies], axis = 1)
df.head()
# Out:
#     Invoice ID Branch Region      City Customer type  Gender  \
# 0  750-67-8428      A  North     Delhi        Member    Male
# 1  226-31-3081      C  South  Banglore        Normal    Male
# 2  631-41-3108      A  North     Delhi        Normal  Female
# 3  123-19-1176      A  North     Delhi        Member  Female
# 4  373-73-7910      A  North     Delhi        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%  ...        Date  \
# 0       Health and beauty       74.69         7   26.14  ...  01-05-2019
# 1  Electronic accessories       15.28         5    3.82  ...  03-08-2019
# 2      Home and lifestyle       46.33         7   16.22  ...  03-03-2019
# 3       Health and beauty       58.22         8   23.29  ...  27-01-2019
# 4       Sports and travel       86.31         7   30.21  ...  25-02-2019
#
#           Time     Month      Payment    cogs  gross margin percentage  \
# 0   1.08.00 PM       May      Ewallet  522.83                     4.76
# ...

# %% [markdown]
# ## For Male

# %%
plt.figure(figsize = (12,6))
sns.barplot(y = 'Product line', x = 'Male', data = df)
plt.show()

# %% [markdown]
# It can be seen that the majority Male population buy Fashion Accessories & Sports and travel from product line.

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'Customer type', y = 'Male', hue="City", data = df)
plt.show()

# %% [markdown]
# Major Males customer from Banglore are of customer type Member & Normal both.

# %%
plt.figure(figsize = (12,6))
sns.lineplot(y = 'Rating', x = 'Male', hue="City", data = df)
plt.show()

# %% [markdown]
# The ratings in banglore and Mumbai are seen on the higher side and lower in Delhi from Male Population.

# %% [markdown]
# ## For Female

# %%
plt.figure(figsize = (12,6))
sns.barplot(y = 'Product line', x = 'Female', data = df)
# Out:
# <AxesSubplot:xlabel='Female', ylabel='Product line'>

# %% [markdown]
# It can be seen that the majority Female population buy Health and Beauty product from product line.

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'Customer type', y = 'Female',hue="City", data = df)
plt.show()

# %% [markdown]
# Major Females customer from Delhi are of customer type Member & Normal both.

# %%
plt.figure(figsize = (12,6))
sns.lineplot(y = 'Rating', x = 'Female', hue="City", data = df)
plt.show()

# %% [markdown]
# The ratings in banglore and Mumbai are seen on the lower side and Higher in Delhi from Female Population.

# %%
df.corr()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633949  0.633961  0.633962
# Quantity                   0.010778  1.000000  0.705525  0.705511  0.705510
# Tax 5%                     0.633949  0.705525  1.000000  1.000000  1.000000
# Total                      0.633961  0.705511  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705508  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036444 -0.036442 -0.036442
# Female                     0.015445 -0.074258 -0.049449 -0.049451 -0.049451
# Male                      -0.015445  0.074258  0.049449  0.049451  0.049451
#
#                          gross margin percentage  gross income    Rating  \
# ...

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1. Supermarket sales data has 19 Columns & 1000 Rows.
#
# 2. Dtypes of the DataFrame is 6 - float64 / 1 - int64 / 12 - object columns.
#
# 3. There is no null values in the data set.
#
# 4. In scatter plot you can see more sales are achived in Jan, Feb, Mar.
#
# 5. In the count plot it can be seen that majorly the customers in Delhi is Female population and in Banglore it's from the Male population
#
# 6. The bar plot shows in overall Region that the payment recieved is more from Ewallet then cash then credit card.
#
# 7. Most Males prefer to pay by cash and most Female prefers to pay by Ewallet in overall Region.
#
# 8. The barplot shows that More sales growth is achieved from south region.
#
# 9. It can be seen that the majority Male population buy Fashion Accessories & Sports and travel from product line.
#
# 10. It can be seen that the majority Female population buy Health and Beauty product from product line.
#
# 11. Major Males customer from Banglore are of customer type Member & Normal both.
#
# 12. The ratings in banglore and Mumbai are seen on the higher side and lower in Delhi from Male Population.
#
# 13. The ratings in banglore and Mumbai are seen on the lower side and Higher in Delhi from Female Population.

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'Region', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Month', 'Payment', 'cogs', 'gross margin percentage',
#        'gross income', 'Rating', 'Female', 'Male'],
#       dtype='object')

# %%
df = df.drop(['Invoice ID', 'Date','Time'], axis = 1)
df.head()
# Out:
#   Branch Region      City Customer type  Gender            Product line  \
# 0      A  North     Delhi        Member    Male       Health and beauty
# 1      C  South  Banglore        Normal    Male  Electronic accessories
# 2      A  North     Delhi        Normal  Female      Home and lifestyle
# 3      A  North     Delhi        Member  Female       Health and beauty
# 4      A  North     Delhi        Normal  Female       Sports and travel
#
#    Unit price  Quantity  Tax 5%   Total     Month      Payment    cogs  \
# 0       74.69         7   26.14  548.97       May      Ewallet  522.83
# 1       15.28         5    3.82   80.22    August         Cash   76.40
# 2       46.33         7   16.22  340.53     March  Credit card  324.31
# 3       58.22         8   23.29  489.05   January      Ewallet  465.76
# 4       86.31         7   30.21  634.38  February      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  Female  Male
# ...

# %%
# Import label encoder 
from sklearn import preprocessing
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'Country'. 
df['Branch']= label_encoder.fit_transform(df['Branch'])
df['Region']= label_encoder.fit_transform(df['Region'])
df['City']= label_encoder.fit_transform(df['City'])
df['Customer type']= label_encoder.fit_transform(df['Customer type'])
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Product line']= label_encoder.fit_transform(df['Product line'])
df['Month']= label_encoder.fit_transform(df['Month'])
df['Payment']= label_encoder.fit_transform(df['Payment'])
print(df.head())
# Out:
#    Branch  Region  City  Customer type  Gender  Product line  Unit price  \
# 0       0       0     1              0       1             3       74.69
# 1       2       1     0              1       1             0       15.28
# 2       0       0     1              1       0             4       46.33
# 3       0       0     1              0       0             3       58.22
# 4       0       0     1              1       0             5       86.31
#
#    Quantity  Tax 5%   Total  Month  Payment    cogs  gross margin percentage  \
# 0         7   26.14  548.97      8        2  522.83                     4.76
# 1         5    3.82   80.22      1        0   76.40                     4.76
# 2         7   16.22  340.53      7        1  324.31                     4.76
# 3         8   23.29  489.05      4        2  465.76                     4.76
# 4         7   30.21  634.38      3        2  604.17                     4.76
#
#    gross income  Rating  Female  Male
# ...

# %%
df = df.drop(['Male'], axis = 1)
df = df.drop(['Female'], axis = 1)

# %%
X=df[['Branch', 'Region', 'City', 'Customer type', 'Gender',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Month', 'Payment', 'cogs', 'gross margin percentage',
       'gross income', 'Rating']]
X
# Out:
#      Branch  Region  City  Customer type  Gender  Product line  Unit price  \
# 0         0       0     1              0       1             3       74.69
# 1         2       1     0              1       1             0       15.28
# 2         0       0     1              1       0             4       46.33
# 3         0       0     1              0       0             3       58.22
# 4         0       0     1              1       0             5       86.31
# ..      ...     ...   ...            ...     ...           ...         ...
# 995       2       1     0              1       0             3       40.35
# 996       1       2     2              1       1             4       97.38
# 997       0       0     1              0       0             2       31.84
# 998       0       0     1              1       0             4       65.82
# 999       0       0     1              0       1             1       88.34
#
# ...

# %%
Y=df[["Total"]]
Y
# Out:
#        Total
# 0     548.97
# 1      80.22
# 2     340.53
# 3     489.05
# 4     634.38
# ..       ...
# 995    42.37
# 996  1022.49
# 997    33.43
# 998    69.11
# 999   649.30
#
# [1000 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   int32
#  1   Region                   1000 non-null   int32
#  2   City                     1000 non-null   int32
#  3   Customer type            1000 non-null   int32
#  4   Gender                   1000 non-null   int32
#  5   Product line             1000 non-null   int32
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Month                    1000 non-null   int32
#  11  Payment                  1000 non-null   int32
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %% [markdown]
# ## Spltting the dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=22)

# %%
X_train.shape
# Out:
# (800, 15)

# %%
y_train.shape
# Out:
# (800, 1)

# %%
X_test.shape
# Out:
# (200, 15)

# %%
y_test.shape
# Out:
# (200, 1)

# %% [markdown]
# ## Linear Regression

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   int32
#  1   Region                   1000 non-null   int32
#  2   City                     1000 non-null   int32
#  3   Customer type            1000 non-null   int32
#  4   Gender                   1000 non-null   int32
#  5   Product line             1000 non-null   int32
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Month                    1000 non-null   int32
#  11  Payment                  1000 non-null   int32
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(X_test)

# %%
y_predict
# Out:
# array([[ 760.45],
#        [ 154.39],
#        [  20.69],
#        [ 277.67],
#        [ 484.52],
#        [ 333.95],
#        [ 110.09],
#        [ 106.5 ],
#        [ 145.58],
#        [  68.99],
#        [ 365.9 ],
#        [ 329.2 ],
#        [ 697.94],
#        [ 814.38],
#        [  99.75],
#        [  93.11],
#        [ 336.56],
#        [ 640.04],
#        [ 291.21],
#        [ 145.07],
#        [ 138.13],
#        [ 300.22],
#        [ 214.94],
#        [  94.24],
#        [ 627.62],
#        [ 548.18],
#        [ 235.75],
#        [ 420.26],
#        [  99.33],
#        [  87.23],
#        [ 195.72],
#        [ 734.71],
#        [ 463.89],
#        [  44.35],
#        [ 529.52],
#        [ 251.72],
#        [  96.14],
#        [  53.15],
#        [ 408.49],
#        [ 143.99],
#        [ 195.26],
#        [ 146.22],
#        [ 112.22],
#        [ 439.22],
#        [  66.87],
#        [ 174.3 ],
#        [ 224.44],
#        [  93.29],
#        [ 864.57],
#        [  53.93],
# ...

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predict)
# Out:
# 1.481836875427689e-13

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predict)
# Out:
# 1.0

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100,random_state=22)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=22)

# %%
y_predi=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predi)
# Out:
# 0.9999511678917699

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predi)
# Out:
# 0.9535130000000208

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(random_state=22)
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=22)

# %%
y_predi=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predi)
# Out:
# 0.9999237173075396

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predi)
# Out:
# 1.3694500000000027

# %% [markdown]
# ## KNN Regression

# %%
from sklearn import neighbors
model=neighbors.KNeighborsRegressor(n_neighbors = 3)
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pre=model.predict(X_test)
y_pre
# Out:
# array([[ 760.72666667],
#        [ 152.11666667],
#        [  20.38      ],
#        [ 276.58      ],
#        [ 483.45333333],
#        [ 337.96      ],
#        [ 109.83333333],
#        [ 106.03      ],
#        [ 145.08333333],
#        [  67.07666667],
#        [ 364.36666667],
#        [ 326.01666667],
#        [ 699.59333333],
#        [ 812.38666667],
#        [  95.17      ],
#        [  93.50666667],
#        [ 336.50666667],
#        [ 634.41666667],
#        [ 291.27333333],
#        [ 147.91      ],
#        [ 140.6       ],
#        [ 298.21      ],
#        [ 212.75666667],
#        [  92.69      ],
#        [ 629.95      ],
#        [ 547.62666667],
#        [ 235.73333333],
#        [ 424.23666667],
#        [  95.17      ],
#        [  88.95666667],
#        [ 195.74      ],
#        [ 732.91666667],
#        [ 463.33      ],
#        [  45.90666667],
#        [ 524.24333333],
#        [ 252.15666667],
#        [  92.15      ],
#        [  48.97333333],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_predi)
# Out:
# 0.9999237173075396

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,y_predi)
# Out:
# 1.3694500000000027
